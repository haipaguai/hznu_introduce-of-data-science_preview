# %% [markdown]
# ## 数据科学导论 第一次作业

# %% [markdown]
# 学号：
#
# 姓名：

# %% [markdown]
# ### 第一题
#
# 了解一下 len 函数的作用（可以通过输入 len? 来查询）。
#
# 如果我们给它传入变量 x，它会返回什么结果？
#
# 运行代码 len (x) 来验证你的判断是否正确。

# %% [markdown]
# ### 第二题
#
# 以下代码存在错误，请帮助修复该代码

# %%
x = 'What's wrong with this string'

# %% [markdown]
# ### 第三题
#
# 请采用变量x和y,来产生句子"Hello World !"

# %% [markdown]
# ### 第四题
#
# 构建一个整数的List[32,21,51,28,26,100,68,56,89,76,19,35],请把list中的数据从小到大排序输出，和从大到小输出，再计算合计值和平均值。

# %% [markdown]
# ### 第五题
#
# 字符串“The theorem that Reverend Thomas Bayes came up with, over 250
# years ago, uses fundamental probability theory to prescribe how
# probabilities or beliefs should change as relevant new information
# arrives. The preceding Keynes quotation captures that spirit. It
# relies on the conditional and total probability and the chain rule; see
# Bishop (2006) and Gelman et al. (2013) for an introduction and
# more.”，分别统计出其中英文字母、空格、数字和其它字符的个数。

# %% [markdown]
# ### 第六题
#
# 判断101-200之间有多少个素数，并输出所有素数。
#
# 判断素数的方法：用一个数分别去除2到sqrt(这个数)，如果能被整除，则表明此数不是素数，反之是素数。

# %% [markdown]
# ### 第七题
#
# 输入学习成绩，利用条件运算符的嵌套来完成此题：学习成绩>=90分的同学用A表示，60-89分之间的用B表示，60分以下的用C表示。

# %% [markdown]
# ### 第八题
#
# 创建以下变量：
# - D：值为 10000 的浮点数
# - r：值为 0.025 的浮点数
# - T：值为 30 的整数
#
# 假设年利率为 2.5%，计算 T 年后支付的金额（D）的现值（即贴现现值）。将计算结果保存到一个名为 PDV 的新变量中，并打印输出结果。
#
# PDV计算公式：
#
# $$ PDV = \frac{D}{(1+r)^T} $$
